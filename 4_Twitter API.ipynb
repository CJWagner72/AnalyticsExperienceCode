# %%
import tweepy as tweepy
import pandas as pd
import os

# %%
# Variables that contain the user credentials to access Twitter API
# Link to accessing Twitter API via Devlopers account 
# https://developer.twitter.com/en/docs/twitter-api/getting-started/guide#:~:text=To%20make%20any%20request%20to,all%20requests%20to%20the%20API.
API_KEY = 'E1q0U2IlTlrbfw2D8dR6t66w1'
API_KEY_SECRET = '0aJ1Ni1bTllJZG18nQgpEkEcc9SR0cM9Vwu9N6ifLi2Yf8PjDn'
ACCESS_TOKEN = '321798811-Czv7S4z5zW0LiukCjOlBnpr4nltfEE5EbtyuDaqC'
ACCESS_TOKEN_SECRET = 'ybydHVavn4528ivocX5BqPT99LHrHSU5J76oFPXrfobYA'

# %%
auth = tweepy.OAuthHandler(API_KEY, API_KEY_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
text_query = 'wildfire -filter:retweets'
count = 100
lang = 'en'
date_since = '2020-10-19'
try:
 # Creation of query method using parameters
 tweets = tweepy.Cursor(api.search,q=text_query,lang = lang, since = date_since).items(count)
 
 # Pulling information from tweets iterable object
 tweets_list = [[tweet.created_at, tweet.id, tweet.text, tweet.user.screen_name, tweet.user.location] for tweet in tweets]
 
 # Creation of dataframe from tweets list
 # Add or remove columns as you remove tweet information
 tweets_df = pd.DataFrame(tweets_list)
 
except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)

# %%
tweets = tweets_df.rename(columns = {0:'CreatedOn',1:'ID',2:'Text', 3:'User', 4:'Location'})

# %%
tweets.head(20)
# Out:
#              CreatedOn                   ID  \
# 0  2020-11-06 02:28:15  1324539060409540613
# 1  2020-11-06 02:22:10  1324537529446662144
# 2  2020-11-06 02:22:09  1324537525235580932
# 3  2020-11-06 02:22:04  1324537504016474113
# 4  2020-11-06 02:21:39  1324537400954101760
# 5  2020-11-06 02:21:27  1324537350547013632
# 6  2020-11-06 02:21:24  1324537335027916800
# 7  2020-11-06 02:19:39  1324536895364354052
# 8  2020-11-06 02:17:21  1324536319255728133
# 9  2020-11-06 02:16:50  1324536188586385414
# 10 2020-11-06 02:16:13  1324536034495991810
# 11 2020-11-06 02:15:30  1324535851376922624
# 12 2020-11-06 02:10:16  1324534535741181952
# 13 2020-11-06 02:09:58  1324534458444230656
# 14 2020-11-06 02:08:17  1324534038057619458
# 15 2020-11-06 02:07:17  1324533784000163840
# 16 2020-11-06 02:06:14  1324533521231339520
# 17 2020-11-06 02:05:58  1324533453493252097
# 18 2020-11-06 02:04:17  1324533030392791045
# 19 2020-11-06 02:03:28  1324532821860503554
#
#                                                  Text             User  \
# 0   @blondedocean John Mayer’s wildfire is my favo...       puta_kinte
# 1   I'm afraid that I might be starting down a sli...   Wildfire_draft
# 2   Running out of wildfire names, Bay season goes...       DeathLocal
# 3   In California, insurers are barred from cancel...    techchronicle
# 4   Look, I know you followed me for wildfire cont...     ericbkennedy
# 5   Ready or Not’ Play Goes Virtual to Teach Kids ...        SCE_JuanL
# 6                              @blondedocean Wildfire          dubeagu
# 7   I've "rock-climbed" to this picturesque spot a...      ToniRDraper
# 8                    @Lycan6574 Not many left either.   Wildfire_draft
# 9   There is nothing worse than the hell the is de...     DannyDravot_
# 10  Parts of Rocky Mountain National Park to reope...      SkonieSkoop
# 11  @GTABiker We need this lady next time a wildfi...      Dirty_Worka
# 12                         @Wildfire_draft Nice truck        Lycan6574
# 13  Please be responsible. 🔥🌲 \n#wildfire #smokey ...     wildlandmike
# 14  @DrKarlynB Its not true. MI posted that # but ...        MATH_0522
# 15  @kdbowlin Oh? He will *drip* with hate and wil...   thealmightymeh
# 16                        @blondedocean wildfire pt.2  xXx_yolanda_xXx
# 17       @Wildfire_draft I don't think you understand        ZephriFox
# 18  @PhilstarNews Some politicians are the real mo...  sakura_wildfire
# 19  You gotta start a wildfire https://t.co/pAJb5q...     NakersUnited
#
#                       Location
# 0
# 1                   Vestal, NY
# 2
# 3                San Francisco
# 4             Toronto, Ontario
# 5              Victorville, CA
# 6              Los Angeles, CA
# 7
# 8                   Vestal, NY
# 9
# 10              Wilmington, DE
# 11                 New England
# 12  North Dakota.. somewhere..
# 13                Honolulu, HI
# 14
# 15
# 16
# 17               Michigan, USA
# 18
# 19

# %%
tweets.to_csv("recent_tweets.csv", index=False)
